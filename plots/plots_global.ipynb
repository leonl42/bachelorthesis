# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append("/home/miri/Documents/bachelorthesis/plots")
from plot_utils import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
path_sgdm_wbn = "../data/sgdm_wbn"
path_adam_wbn = "../data/adam_wbn"
path_sgdm_wobn = "../data/sgdm_wobn"
path_adam_wobn = "../data/adam_wobn"
image_path = "./images"

# %%
fig,axs = plot_mean_or_norm([f"{path_sgdm_wbn}/noreg/0.025",f"{path_adam_wbn}/noreg/0.00278",f"{path_sgdm_wobn}/noreg/0.0128",f"{path_adam_wobn}/noreg/0.0002"],
                            ["1","2","3","4"],
                            "mg_spacing_0",max_step=100000)
fig.set_size_inches(12,3)
fig.tight_layout()

# %%
fig,axs = plot_mean_or_norm([f"{path_sgdm_wbn}/noreg/0.025",f"{path_adam_wbn}/noreg/0.00278"],
                            [r"SgdM | with Batch Norm | Noreg $lr=0.025$",r"Adam | with Batch Norm | Noreg $lr=0.00278$"],
                            [colors["noreg"],colors["noreg"]],
                            "mg_spacing_0",plot_mean=False,max_step=100000)
axs[0].set_ylabel(r"$||(w_{conv})_{\cdot \cdot \cdot c}||_2$",font={"weight":"bold"},labelpad=10)
fig.set_size_inches(12,3)
fig.tight_layout()
fig.savefig(f"{image_path}/sgdm_wbn_vs_adam_wbn_noreg_output_channel_norms",dpi=1200)
